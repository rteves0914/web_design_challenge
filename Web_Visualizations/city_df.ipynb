# %%
import pandas as pd

# %%
csv = pd.read_csv("city_df.csv")
city_df = pd.DataFrame(csv)

# %%
city_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Kindu  -2.95   25.95     70.50        93          98        1.32
# 1         Dauphin  51.15 -100.05     26.60        92          90       14.99
# 2  Saint-Philippe -21.36   55.77     75.20        78          53        8.99
# 3      Port Hardy  50.70 -127.42     42.80       100          90        4.70
# 4     San Quintín  30.48 -115.95     61.52        68           3        3.67
#
#   Country        Date
# 0      CD  1606238556
# 1      CA  1606238557
# 2      RE  1606238558
# 3      CA  1606238558
# 4      MX  1606238558

# %%
city_df.to_html()
# Out:
#       <th>463</th>\n      <td>Lázaro Cárdenas</td>\n      <td>17.96</td>\n      <td>-102.20</td>\n      <td>84.72</td>\n      <td>61</td>\n      <td>13</td>\n      <td>2.80</td>\n      <td>MX</td>\n      <td>1606238784</td>\n    </tr>\n    <tr>\n      <th>464</th>\n      <td>Champerico</td>\n      <td>14.30</td>\n      <td>-91.92</td>\n      <td>87.80</td>\n      <td>58</td>\n      <td>20</td>\n      <td>4.70</td>\n      <td>GT</td>\n      <td>1606238784</td>\n    </tr>\n    <tr>\n      <th>465</th>\n      <td>Alice Springs</td>\n      <td>-23.70</td>\n      <td>133.88</td>\n      <td>73.40</td>\n      <td>43</td>\n      <td>2</td>\n      <td>3.36</td>\n      <td>AU</td>\n      <td>1606238625</td>\n    </tr>\n    <tr>\n      <th>466</th>\n      <td>Pimenteiras</td>\n      <td>-6.25</td>\n      <td>-41.42</td>\n      <td>96.24</td>\n      <td>33</td>\n      <td>29</td>\n      <td>6.35</td>\n      <td>BR</td>\n      <td>1606238785</td>\n    </tr>\n    <tr>\n      <th>467</th>\n      <t
# ...
